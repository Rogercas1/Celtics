# %% [markdown]
# ### Connect with Website

# %%
url = "https://www.basketball-reference.com/players/t/tatumja01/gamelog/2022"

# %%
import requests
data = requests.get(url)

# %%
with open("Jayson.html", "w+") as f:
        f.write(data.text)

# %%
from bs4 import BeautifulSoup

# %%
with open("Jayson.html") as f:
    page = f.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
Tatum = soup.find(id="pgl_basic")

# %%
import pandas as pd
df = pd.read_html(str(Tatum))[0]

# %%
df
# Out:
#     Rk    G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7        GS  \
# 0    1    1  2021-10-20  23-231  BOS          @  NYK     L (-4)         1
# 1    2    2  2021-10-22  23-233  BOS        NaN  TOR    L (-32)         1
# 2    3    3  2021-10-24  23-235  BOS          @  HOU    W (+10)         1
# 3    4    4  2021-10-25  23-236  BOS          @  CHO    W (+11)         1
# 4    5    5  2021-10-27  23-238  BOS        NaN  WAS     L (-9)         1
# ..  ..  ...         ...     ...  ...        ...  ...        ...       ...
# 81  79   74  2022-04-03  24-031  BOS        NaN  WAS    W (+42)         1
# 82  80   75  2022-04-06  24-034  BOS          @  CHI    W (+23)         1
# 83  Rk    G        Date     Age   Tm        NaN  Opp        NaN        GS
# 84  81  NaN  2022-04-07  24-035  BOS          @  MIL     L (-6)  Inactive
# 85  82   76  2022-04-10  24-038  BOS          @  MEM    W (+29)         1
#
#           MP  ...       DRB       TRB       AST       STL       BLK       TOV  \
# ...

# %% [markdown]
# ### Remove unneccessary columns

# %%
df.drop('G', axis=1, inplace=True)

# %%
df.drop('Age', axis = 1, inplace=True)

# %%
df.drop('Tm', axis = 1, inplace=True)

# %%
df
# Out:
#     Rk        Date Unnamed: 5  Opp Unnamed: 7        GS        MP        FG  \
# 0    1  2021-10-20          @  NYK     L (-4)         1     44:37         7
# 1    2  2021-10-22        NaN  TOR    L (-32)         1     30:20         8
# 2    3  2021-10-24          @  HOU    W (+10)         1     36:54        12
# 3    4  2021-10-25          @  CHO    W (+11)         1     41:28        14
# 4    5  2021-10-27        NaN  WAS     L (-9)         1     35:40         9
# ..  ..         ...        ...  ...        ...       ...       ...       ...
# 81  79  2022-04-03        NaN  WAS    W (+42)         1     29:09         9
# 82  80  2022-04-06          @  CHI    W (+23)         1     30:09         5
# 83  Rk        Date        NaN  Opp        NaN        GS        MP        FG
# 84  81  2022-04-07          @  MIL     L (-6)  Inactive  Inactive  Inactive
# 85  82  2022-04-10          @  MEM    W (+29)         1     26:03        11
#
# ...

# %%
df.drop(df.index[(df["GS"] == "Inactive")],axis=0,inplace=True)

# %%
df.drop(df.index[(df["Rk"] == "Rk")],axis=0,inplace=True)

# %%
df
# Out:
#     Rk        Date Unnamed: 5  Opp Unnamed: 7 GS     MP  FG FGA   FG%  ...  \
# 0    1  2021-10-20          @  NYK     L (-4)  1  44:37   7  30  .233  ...
# 1    2  2021-10-22        NaN  TOR    L (-32)  1  30:20   8  14  .571  ...
# 2    3  2021-10-24          @  HOU    W (+10)  1  36:54  12  24  .500  ...
# 3    4  2021-10-25          @  CHO    W (+11)  1  41:28  14  28  .500  ...
# 4    5  2021-10-27        NaN  WAS     L (-9)  1  35:40   9  22  .409  ...
# ..  ..         ...        ...  ...        ... ..    ...  ..  ..   ...  ...
# 79  77  2022-03-30        NaN  MIA     L (-8)  1  39:35   9  17  .529  ...
# 80  78  2022-04-01        NaN  IND     W (+5)  1  37:13  10  24  .417  ...
# 81  79  2022-04-03        NaN  WAS    W (+42)  1  29:09   9  17  .529  ...
# 82  80  2022-04-06          @  CHI    W (+23)  1  30:09   5  18  .278  ...
# 85  82  2022-04-10          @  MEM    W (+29)  1  26:03  11  14  .786  ...
#
#    DRB TRB AST STL BLK TOV PF PTS  GmSc  +/-
# ...

# %% [markdown]
# ### Rename columns with no names

# %%
df.rename(columns = {'Unnamed: 5':'H or A'}, inplace = True)

# %%
df.rename(columns = {'Unnamed: 7':'Result'}, inplace = True)

# %%
df
# Out:
#     Rk        Date H or A  Opp   Result GS     MP  FG FGA   FG%  ... DRB TRB  \
# 0    1  2021-10-20      @  NYK   L (-4)  1  44:37   7  30  .233  ...   7  11
# 1    2  2021-10-22    NaN  TOR  L (-32)  1  30:20   8  14  .571  ...   6   6
# 2    3  2021-10-24      @  HOU  W (+10)  1  36:54  12  24  .500  ...   9   9
# 3    4  2021-10-25      @  CHO  W (+11)  1  41:28  14  28  .500  ...   6   7
# 4    5  2021-10-27    NaN  WAS   L (-9)  1  35:40   9  22  .409  ...   6   7
# ..  ..         ...    ...  ...      ... ..    ...  ..  ..   ...  ...  ..  ..
# 79  77  2022-03-30    NaN  MIA   L (-8)  1  39:35   9  17  .529  ...   4   5
# 80  78  2022-04-01    NaN  IND   W (+5)  1  37:13  10  24  .417  ...   4   6
# 81  79  2022-04-03    NaN  WAS  W (+42)  1  29:09   9  17  .529  ...   4   6
# 82  80  2022-04-06      @  CHI  W (+23)  1  30:09   5  18  .278  ...  10  10
# 85  82  2022-04-10      @  MEM  W (+29)  1  26:03  11  14  .786  ...   9   9
#
#    AST STL BLK TOV PF PTS  GmSc  +/-
# ...

# %%
import numpy as np
df['H or A'] = df['H or A'].replace(['@'],'A')
df['H or A'] = df['H or A'].replace([np.nan],'H')

# %%
df
# Out:
#     Rk        Date H or A  Opp   Result GS     MP  FG FGA   FG%  ... DRB TRB  \
# 0    1  2021-10-20      A  NYK   L (-4)  1  44:37   7  30  .233  ...   7  11
# 1    2  2021-10-22      H  TOR  L (-32)  1  30:20   8  14  .571  ...   6   6
# 2    3  2021-10-24      A  HOU  W (+10)  1  36:54  12  24  .500  ...   9   9
# 3    4  2021-10-25      A  CHO  W (+11)  1  41:28  14  28  .500  ...   6   7
# 4    5  2021-10-27      H  WAS   L (-9)  1  35:40   9  22  .409  ...   6   7
# ..  ..         ...    ...  ...      ... ..    ...  ..  ..   ...  ...  ..  ..
# 79  77  2022-03-30      H  MIA   L (-8)  1  39:35   9  17  .529  ...   4   5
# 80  78  2022-04-01      H  IND   W (+5)  1  37:13  10  24  .417  ...   4   6
# 81  79  2022-04-03      H  WAS  W (+42)  1  29:09   9  17  .529  ...   4   6
# 82  80  2022-04-06      A  CHI  W (+23)  1  30:09   5  18  .278  ...  10  10
# 85  82  2022-04-10      A  MEM  W (+29)  1  26:03  11  14  .786  ...   9   9
#
#    AST STL BLK TOV PF PTS  GmSc  +/-
# ...

# %%
df.to_csv("Tatum.csv")
